# %%
import librosa
from utils.util import read_audio
import matplotlib.pyplot as plt
normal = 'data/wav_example/a0007.wav'
abnormal = 'data/wav_example/a0001.wav'

# %%
y, sr = read_audio(normal, filter=False)
plt.plot(y[:2000*2])
plt.ylabel("Amplitude")
plt.xlabel("Time")
plt.show()

# %%
y, sr = read_audio(normal, filter=True)
plt.plot(y[:2000*2])
plt.ylabel("Amplitude")
plt.xlabel("Time")
plt.show()

# %%
y, sr = read_audio(abnormal, filter=False)
plt.plot(y[:2000*2])
plt.ylabel("Amplitude")
plt.xlabel("Time")
plt.show()

# %%
y, sr = read_audio(abnormal, filter=True)
plt.plot(y[:2000*2])
plt.ylabel("Amplitude")
plt.xlabel("Time")
plt.show()

# %%
from utils.audio_feature_extractor import LogMelExtractor
import numpy as np
import librosa.display
y, sr = read_audio(normal, filter=False)
MEL_ARGS={
    'n_mels':128,
    'sr':sr,
    'hop_length':int(sr*15/1000),
    'win_length':int(sr*25/1000)
}
EPS = 1E-6
melspectrogram = librosa.feature.melspectrogram(y=y[:8000], sr=sr, n_mels=128,
                                    hop_length=30,win_length=50)
lms = np.log(melspectrogram+EPS)
plt.imshow(lms,origin='lower')
plt.ylabel("Mels D=128")
plt.xlabel("Time")
plt.axis('off')
# Out:
# (-0.5, 266.5, -0.5, 127.5)
